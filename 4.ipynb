# %% [markdown]
# # Techniques - التقنيات

# %% [markdown]
# المصفوفات ذات أهمية عالية جداً في علم البيانات والذكاء الاصطناعي بشكل خاص وكذلك قد تحتاج إليها في مجالات أخرى مثل الحوسبة العلمية وتطوير الويب

# %% [markdown]
# هنا سأكتب أهم الأدوات والتقنيات التي تدعمك في مجال علم البيانات بشكل عام :

# %% [markdown]
# ### Programming languages - لغات برمجة
# 1. Python
# 2. R
# 3. SQL
# 4. Julia

# %% [markdown]
# ### Tools - أدوات
#
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebook  |
# | RStudio          |
# | Apache Zeppelin  |

# %% [markdown]
# والآن سأتكلم بشكل خاص عن أهم شيئين في عالم برمجة المصفوفات :

# %% [markdown]
# - Python : وهي لغة البرمجة التي ذكرتها مسبقاً في هذا الفصل وفصول أخرى
# - NumPy : وهي مكتبة رئيسية للرياضيات المتقدمة ومن ضمنها المصفوفات خاصة بلغة بايثون
#
# `NumPy = Numerical Python`

# %% [markdown]
# ### End - نهاية الفصل
