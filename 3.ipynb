# %% [markdown]
# # Python simple review - مراجعة بسيطة لبايثون

# %% [markdown]
# ## مقدمة

# %% [markdown]
# لغة بايثون هي لغة برمجة عالية المستوى تم انشائها من قبل جويدو فان روسوم في عام 1991 , وتعد لغة من لغات البرمجة الشيئية ولغة قوية جداً وبسيطة وسهلة التعلم للمبتدئين ويتم إستخدامها بكثافة في كلاً من :
# - تطوير الويب الخلفي
#
# بإستخدام مكتبات مثل :
#
#
# 1. Flask
# 2. Django
#
# - الأمن السيبراني
# حيث تمتلك العديد من المقومات والأدوات في هذا المجال , وهناك كتاب كامل قد يفيدك يدعى :
# `Black Hat Python`
#
# - علم البيانات
# حيث تستخدم في تحليل البيانات وتعلم الآلة وحتى الأتمتة وسحب البيانات من الويب
#
# - الذكاء الاصطناعي
# وهو من أقوى المجالات التي يستخدم فيها هذه اللغة البرمجية , لإمتلاكها العديد من المكتبات والأدوات في تعلم الآلة والتعلم العميق أبرزها :
#
#
# 1. Scikit Learn
# 2. SciPy
# 3. PyTorch
# 4. Tensorflow

# %% [markdown]
# ### أوامر

# %%
print("Hello world")

# أمر الطباعة - Print command
# Out:
# Hello world

# %%
x = 10

# متغير - Variable
# ولانحتاج لتعريف نوعه عكس جافا وسي بلس بلس , المتغير من قيمته يتم تعريفه من اللغة نفسها

# %%
print(x)

# طباعة متغير مخزن مسبقاً
# وهو في الأمر السابق
# Out:
# 10

# %%
# طباعة نص مع متغير

print("The x equals : " , x)

# لابد أن نجعل هناك فاصلة بين النص المطبوع والمتغير الذي سيتم طباعته
# Out:
# The x equals :  10

# %%
# استخدام مكتبة

import time
import os
import math

# يمكننا استخدام المكتبات الآتية في مشروعنا

# %%
# تحميل مكتبة خارجية
# عن طريق أمر pip

# pip install pandas
# مثلاً

#سيحمله لك عن طريق الويب

# %%
# تضمين مكتبة خارجية تم تحميلها

import pandas

# %%
# اختصار اسم المكتبة

import pandas as pd
import numpy as np

# الآن نستخدم الاختصار لكل أمر وليس اسم المكتبة الخارجية نفسها

# %%
# أمر الانبوت/الادخال

yourname = input("Enter your name : ")

print ("Your name is : " , yourname)
# Out:
# Enter your name :  Saad
# Your name is :  Saad

# %%
if (x<9):
    print ("Correct")
else:
    print ("False")

# الاكس عرفناها مسبقاً بأنها 10

# هنا أمر الif else
# إن كانت الاكس اقل من 9 اكتب صح
# غير ذلك اكتب خطأ
# لأنه غير ذلك طبع لنا خطأ
# Out:
# False

# %% [markdown]
# ### راجع الآتي لو كنت تود التعمق :
# - While Loop
# - Do While
# - Files and directories management
# - Install libraries

# %% [markdown]
# ---

# %% [markdown]
# ### End - نهاية الفصل
