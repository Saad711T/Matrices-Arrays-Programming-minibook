# %% [markdown]
# # Welcome to matrices programming - مرحباً بكم في كتاب برمجة المصفوفات

# %% [markdown]
# <p align="center">
#   <img src="logo.png" width="250px" alt="logo" />
# </p>

# %% [markdown]
# ### Credits - تأليف

# %% [markdown]
# [0xSaad](https://x.com/0xdonzdev)

# %% [markdown]
# ## Syllabus - الفهرس

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Python-logo-notext.svg/1200px-Python-logo-notext.svg.png" width="250px" alt="python" />

# %% [markdown]
# - [Introduction to arrays and matrices - مقدمة في المصفوفات](2.ipynb)
# - [Python simple review - مراجعة بسيطة لبايثون](3.ipynb)
# - [Techniques - التقنيات](4.ipynb)
# - [Usage of NumPy - إستخدام مكتبة نمباي](5.ipynb)
# - [Summary - الخلاصة](summary.ipynb)

# %% [markdown]
# Thx for read that - شكراً جزيلاً لك لقراءتك الكتاب

# %%
print("End")
# Out:
# End
